# %% [markdown]
# **[Time-Table]** \
# 2021_09_15 생성 \
# 2021_09_19 수정 : 목차 변환 및 자료추가

# %% [markdown]
# # **A. Dataframe**
# 1.   데이터프레임 조작
#   - 데이터프레임 행<->열 변환
#
#       `df.T`
#       `df.transpose()`
#
#
#   - 데이터프레임 컬럼명 재설정 /   [0번 인덱스 열] 로 컬럼명 설정
#
#       `df.rename(columns=df.iloc[0])`
#
#
#   - 데이터프레임 인덱스 삭제 / 열 삭제 / [0번 인덱스 열] 삭제
#
#       `df.drop(df.index[0])`
#
#
#   - 데이터프레임 결측치 대체하기 (0)
#
#       `df.fillna(0)`
#
#
# 2.   데이터프레임 확인
#   - 데이터의 dimension 확인
#
#         `df.shape`
#
#
#   - 데이터의 결측치 확인 (결측값 True 표시)
#
#         `df.isnull()`
#
#
#   - column 당 데이터 결측치 확인
#
#         `df.isnull().sum()`
#
#
#   - 데이터프레임 헤드 확인 (10줄)
#
#         `df.head(10)`
#
#
# 3.   데이터프레임 응용
#   - 특정 숫자보다 크거나 작은 셀의 합 구하기
#
# ```
# FP11 = FP1.values.tolist() #데이터프레임의 값을 리스트로 변환
# FP22 = FP2.values.tolist()
#
# FPS = FP11 + FP22 #두 리스트를 합침(?) 아, 두 데이터프레임의 총합이라서 합친것임.
# num1 = int()
# num2 = int()
# for i in FPS:
#   if i > 0:
#     num1=num1+1
#   if i < 0:
#     num2=num2+1
# ```

# %% [markdown]
# # **B. Pandas**
# 1.   판다스 라이브러리 호출
#
#       `import pandas as pd`
#
#
# 2.   데이터 불러오기
#
#   - xlsx : `df = pd.read_excel(io=excel_url, sheet_name='008770 ')`
#   - csv :
#
#
# 3.   데이터 내보내기
#
#   - xlsx :
#   - csv : `df.to_csv("df.csv", header=False, index=False)`

# %% [markdown]
# ## **C. Visualization**
# 1. 시각화 라이브러리 호출
#
#         `import seaborn as sns`
#         `import matplotlib.pyplot as plt`
#
# 2. barplot 시각화
#
#   -  내장 라이브러리 시각화
#
#         `df.FCF.plot.bar()` FCF = Dataframe column name
#         `barh()`사용시 그래픽 수직으로 변환
#
#   -  seaborn 시각화
#
#         `sns.barplot(data= df,x= df.index[:],y= "FCF")`
